# %% [markdown]
# # データ型と演算子

# %% [markdown]
# ### 整数型と浮動小数点数型

# %%
1 + 1
# Out:
# 2

# %%
1.0 + 1.0
# Out:
# 2.0

# %%
1 + 1.0
# Out:
# 2.0

# %%
type(1 + 1)
# Out:
# int

# %%
type(1.0 + 1.0)
# Out:
# float

# %%
1 / 2
# Out:
# 0.5

# %%
type(1 / 2)
# Out:
# float

# %% [markdown]
# ### 文字列型と算術演算子

# %%
'こんにちは'
# Out:
# 'こんにちは'

# %%
type('こんにちは')
# Out:
# str

# %%
'こんにちは ' + 'わたしは ' + '学生です'
# Out:
# 'こんにちは わたしは 学生です'

# %%
'こんにちは ' + 'わたしは ' + 2 + '年生です'

# %%
'こんにちは ' + 'わたしは ' + str(2) + '年生です'
# Out:
# 'こんにちは わたしは 2年生です'

# %% [markdown]
# ### ブール型

# %%
1 > 0

# %%
type(1 > 0)

# %%
1 >= 0

# %%
1 == 0

# %%
1 != 0
# Out:
# True

# %% [markdown]
# ### 変数

# %%
a = 'こんにちは '
b = 'わたしは '
c = '学生です'
a + b + c

# %%
a = 'こんにちは '
b = 'わたしは '
c = '年生です'
n = 2    # 学年
a + b + str(n) + c
# Out:
# 'こんにちは わたしは 2年生です'
