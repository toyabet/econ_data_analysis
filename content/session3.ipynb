# %% [markdown]
# # データ型と演算子②

# %% [markdown]
# ## list（リスト）

# %%
numbers = [10, 20, 30, 40]
numbers
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ### インデックスによるアクセス

# %%
numbers[0]
# Out:
# 10

# %%
numbers[1]
# Out:
# 2

# %%
numbers[2]
# Out:
# 30

# %%
numbers[3]
# Out:
# 40

# %%
numbers[-1]
# Out:
# 40

# %%
numbers[-2]
# Out:
# 30

# %%
numbers[-3]
# Out:
# 20

# %%
numbers[-4]
# Out:
# 10

# %% [markdown]
# ### スライス

# %%
numbers[-2:3]
# Out:
# [30]

# %%
numbers[1:-1]
# Out:
# [20, 30]

# %% [markdown]
# ### 入れ子構造のリスト

# %%
numbers = [10, 20, 30, [40, 50]]
numbers
# Out:
# [10, 20, 30, [40, 50]]

# %%
numbers[0]
# Out:
# 10

# %%
numbers[3]
# Out:
# [40, 50]

# %%
numbers[3][0]
# Out:
# 40

# %%
numbers[3][1]
# Out:
# 50

# %%
numbers[0] = 100
numbers
# Out:
# [100, 20, 30, [40, 50]]

# %%
numbers[3] = 400
numbers
# Out:
# [10, 20, 30, 400]

# %% [markdown]
# ### 要素の追加・削除

# %%
numbers.append(500)
numbers
# Out:
# [10, 20, 30, 400, 500]

# %%
del numbers[0]
numbers
# Out:
# [20, 30, 400, 500]

# %%
numbers[0]
# Out:
# 20

# %% [markdown]
# ### dict (辞書)

# %%
item = {
    "name": "pen",
    "price": 120,
    "stock": 15
}
item
# Out:
# {'name': 'pen', 'price': 120, 'stock': 15}

# %%
item["color"] = "black"
item
# Out:
# {'name': 'pen', 'price': 120, 'stock': 16, 'color': 'black'}

# %%
item.update(color = "black")
item
# Out:
# {'name': 'pen', 'price': 120, 'stock': 15, 'color': 'black'}

# %%
item.keys()
# Out:
# dict_keys(['name', 'price', 'stock', 'color'])

# %%
item.values()
# Out:
# dict_values(['pen', 120, 15, 'black'])

# %%
numbers1 = [1, 2, 3]
numbers2 = [4, 5, 6]
numbers = numbers1 + numbers2
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
text = "economics"
text[0]
# Out:
# 'e'

# %%
text[:5]
# Out:
# 'econo'

# %%
numbers = [10, 20, 30, 40]
10 in numbers
# Out:
# True

# %%
1000 in numbers
# Out:
# False

# %%
item = {"name": "pen", "price": 120, "stock": 15}
"name" in item
# Out:
# True

# %%
"pen" in item
# Out:
# True

# %%
"pen" in item.values()
# Out:
# True
